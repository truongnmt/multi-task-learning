# %%
import CNN2Head_input2 as CNN2Head_input
import os
import tensorflow as tf
import numpy as np
import BKNetStyle2 as BKNetStyle
from const import *
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
''' PREPARE DATA '''
''' PREPARE DATA '''
smile_train, smile_test = CNN2Head_input.getSmileImage()
gender_train, gender_test = CNN2Head_input.getGenderImage()
age_train, age_test = CNN2Head_input.getAgeImage()
'''-------------------------------------git lfs install
-------------------------------------------------------'''
# Out:
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  150000
# ---------------------------------------------------------------
# Load age image...................
# Done !
# Number of age train data:  150000
# ---------------------------------------------------------------
# '--------------------------------------------------------------------------------------------'

# %%
def one_hot(index, num_classes):
    assert index < num_classes and index >= 0
    tmp = np.zeros(num_classes, dtype=np.float32)
    tmp[index] = 1.0
    return tmp

# %%
if __name__ == "__main__":
    sess = tf.InteractiveSession()
    global_step = tf.contrib.framework.get_or_create_global_step()

    x, y_, mask = BKNetStyle.Input()

    y_smile_conv, y_gender_conv, y_age_conv, phase_train, keep_prob = BKNetStyle.BKNetModel(x)
    smile_loss, gender_loss, age_loss, l2_loss, loss = BKNetStyle.selective_loss(y_smile_conv, y_gender_conv,
                                                                                 y_age_conv, y_, mask)

    train_step = BKNetStyle.train_op(loss, global_step)

    smile_mask = tf.get_collection('smile_mask')[0]
    gender_mask = tf.get_collection('gender_mask')[0]
    age_mask = tf.get_collection('age_mask')[0]

    y_smile = tf.get_collection('y_smile')[0]
    y_gender = tf.get_collection('y_gender')[0]
    y_age = tf.get_collection('y_age')[0]

    smile_correct_prediction = tf.equal(tf.argmax(y_smile_conv, 1), tf.argmax(y_smile, 1))
    gender_correct_prediction = tf.equal(tf.argmax(y_gender_conv, 1), tf.argmax(y_gender, 1))
    age_correct_prediction = tf.equal(tf.argmax(y_age_conv, 1), tf.argmax(y_age, 1))

    smile_true_pred = tf.reduce_sum(tf.cast(smile_correct_prediction, dtype=tf.float32) * smile_mask)
    gender_true_pred = tf.reduce_sum(tf.cast(gender_correct_prediction, dtype=tf.float32) * gender_mask)
    age_true_pred = tf.reduce_sum(tf.cast(age_correct_prediction, dtype=tf.float32) * age_mask)

    train_data = []
    # Mask: Smile -> 0, Gender -> 1, Age -> 2
    for i in range(len(smile_train) * 10):
        img = (smile_train[i % 3000][0] - 128) / 255.0
        label = smile_train[i % 3000][1]
        train_data.append((img, one_hot(label, 101), 0.0))
    for i in range(len(gender_train)):
        img = (gender_train[i][0] - 128) / 255.0
        label = (int)(gender_train[i][1])
        train_data.append((img, one_hot(label, 101), 1.0))
    for i in range(len(age_train)):
        img = (age_train[i][0] - 128) / 255.0
        label = (int)(age_train[i][1])
        train_data.append((img, one_hot(label, 101), 2.0))

    saver = tf.train.Saver()

    if not os.path.isfile(SAVE_FOLDER2 + 'model-age101.ckpt.index'):
        print('Create new model')
        sess.run(tf.global_variables_initializer())
        print('OK')
    else:
        print('Restoring existed model')
        saver.restore(sess, SAVE_FOLDER2 + 'model-age101.ckpt')
        print('OK')

    loss_summary_placeholder = tf.placeholder(tf.float32)
    tf.summary.scalar('loss', loss_summary_placeholder)
    merge_summary = tf.summary.merge_all()
    writer = tf.summary.FileWriter("./summary/")

    learning_rate = tf.get_collection('learning_rate')[0]
    current_epoch = (int)(global_step.eval() / (len(train_data) // BATCH_SIZE))
    for epoch in range(current_epoch + 1, NUM_EPOCHS):
        print('Epoch:', str(epoch))
        np.random.shuffle(train_data)
        train_img = []
        train_label = []
        train_mask = []

        for i in range(len(train_data)):
            train_img.append(train_data[i][0])
            train_label.append(train_data[i][1])
            train_mask.append(train_data[i][2])

        number_batch = len(train_data) // BATCH_SIZE

        avg_ttl = []
        avg_rgl = []
        avg_smile_loss = []
        avg_gender_loss = []
        avg_age_loss = []

        smile_nb_true_pred = 0
        gender_nb_true_pred = 0
        age_nb_true_pred = 0

        smile_nb_train = 0
        gender_nb_train = 0
        age_nb_train = 0

        print("Learning rate: %f" % learning_rate.eval())
    #     for batch in range(number_batch):
        for batch in range(number_batch):
    #         if (batch+1)%100==0:
    #             print('Training on batch {0}/{1}'.format(str(batch + 1), str(number_batch)))
            top = batch * BATCH_SIZE
            bot = min((batch + 1) * BATCH_SIZE, len(train_data))
            batch_img = np.asarray(train_img[top:bot])
            batch_label = np.asarray(train_label[top:bot])
            batch_mask = np.asarray(train_mask[top:bot])

            for i in range(BATCH_SIZE):
                if batch_mask[i] == 0.0:
                    smile_nb_train += 1
                else:
                    if batch_mask[i] == 1.0:
                        gender_nb_train += 1                        
                    else:
                        age_nb_train += 1

            batch_img = CNN2Head_input.augmentation(batch_img, 48)

            ttl, sml, gel, agl, l2l, _ = sess.run([loss, smile_loss, gender_loss, age_loss, l2_loss, train_step],
                                                  feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                             phase_train: True,
                                                             keep_prob: 0.5})

            smile_nb_true_pred += sess.run(smile_true_pred, feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                                       phase_train: True,
                                                                       keep_prob: 0.5})

            gender_nb_true_pred += sess.run(gender_true_pred,
                                            feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                       phase_train: True,
                                                       keep_prob: 0.5})

            age_nb_true_pred += sess.run(age_true_pred,
                                             feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                        phase_train: True,
                                                        keep_prob: 0.5})

            '''--------------------------------------- DEBUG -----------------------------------------------------'''
            '''
            sm_mask, em_mask, ge_mask = sess.run([smile_mask, gender_mask, age_mask],
                                                 feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                            phase_train: True,
                                                            keep_prob: 0.5})
            print('Smile mask: ', sm_mask)
            print('Gender mask', ge_mask)
            print('Age mask', ag_mask)
            print('Batch mask', batch_mask)

            y_true_sm, y_true_ge, y_true_ag = sess.run([y_smile, y_gender, y_age],
                                                       feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                                  phase_train: True,
                                                                  keep_prob: 0.5})
            print('Smile label', y_true_sm)
            print('Gender label', y_true_ge)
            print('Age label', y_true_ag)
            print('Batch label', batch_label)

            y_conv_sm, y_conv_ge, y_conv_ag = sess.run([y_smile_conv, y_gender_conv, y_age_conv],
                                                       feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
                                                                  phase_train: True,
                                                                  keep_prob: 0.5})
            print('Smile conv', y_conv_sm)
            print('Gender conv', y_conv_ge)
            print('Age conv', y_conv_ag)

            '''
            '''---------------------------------- END OF DEBUG ----------------------------------------------------'''

            avg_ttl.append(ttl)
            avg_smile_loss.append(sml)
            avg_gender_loss.append(gel)
            avg_age_loss.append(agl)

            avg_rgl.append(l2l)

        smile_train_accuracy = smile_nb_true_pred * 1.0 / smile_nb_train
        gender_train_accuracy = gender_nb_true_pred * 1.0 / gender_nb_train
        age_train_accuracy = age_nb_true_pred * 1.0 / age_nb_train

        avg_smile_loss = np.average(avg_smile_loss)
        avg_gender_loss = np.average(avg_gender_loss)
        avg_age_loss = np.average(avg_age_loss)

        avg_rgl = np.average(avg_rgl)
        avg_ttl = np.average(avg_ttl)

        summary = sess.run(merge_summary, feed_dict={loss_summary_placeholder: avg_ttl})
        writer.add_summary(summary, global_step=epoch)

        print('\n')

        print('Smile task train accuracy: ' + str(smile_train_accuracy * 100))
        print('Gender task train accuracy: ' + str(gender_train_accuracy * 100))
        print('Age task train accuracy: ' + str(age_train_accuracy * 100))

        print('Total loss: ' + str(avg_ttl) + '. L2-loss: ' + str(avg_rgl))
        print('Smile loss: ' + str(avg_smile_loss))
        print('Gender loss: ' + str(avg_gender_loss))
        print('Age loss: ' + str(avg_age_loss))

        saver.save(sess, SAVE_FOLDER2 + 'model-age101.ckpt')
# Out:
# WARNING:tensorflow:From <ipython-input-4-3092e8de3f07>:3: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# Create new model
# OK
# Epoch: 1
# Learning rate: 0.010000
#
#
# Smile task train accuracy: 62.7817042272
# Gender task train accuracy: 66.7573387737
# Age task train accuracy: 3.7520750415
# Total loss: 7.27729. L2-loss: 1.96636
# Smile loss: 0.661976
# Gender loss: 0.631072
# Age loss: 4.01788
# Epoch: 2
# Learning rate: 0.009025
#
#
# Smile task train accuracy: 83.99279976
# Gender task train accuracy: 64.6465858634
# Age task train accuracy: 3.73755758679
# Total loss: 5.4092. L2-loss: 0.308721
# Smile loss: 0.457964
# Gender loss: 0.642581
# Age loss: 3.99993
# Epoch: 3
# Learning rate: 0.007738
#
#
# Smile task train accuracy: 89.3289328933
# Gender task train accuracy: 64.3523827302
# Age task train accuracy: 3.66221973318
# Total loss: 5.30216. L2-loss: 0.310855
# Smile loss: 0.354413
# Gender loss: 0.643912
# Age loss: 3.99298
# Epoch: 4
# Learning rate: 0.006983
#
#
# Smile task train accuracy: 90.8660577372
# Gender task train accuracy: 66.0397610603
# Age task train accuracy: 3.66024401627
# Total loss: 5.25532. L2-loss: 0.304444
# Smile loss: 0.335636
# Gender loss: 0.628425
# Age loss: 3.98681
# Epoch: 5
# Learning rate: 0.005987
#
#
# Smile task train accuracy: 92.7192719272
# Gender task train accuracy: 77.8887436998
# Age task train accuracy: 3.85756478722
# Total loss: 5.11083. L2-loss: 0.335346
# Smile loss: 0.302357
# Gender loss: 0.50218
# Age loss: 3.97095
# Epoch: 6
# Learning rate: 0.005404
#
#
# Smile task train accuracy: 93.4862324155
# Gender task train accuracy: 79.9441318435
# Age task train accuracy: 3.98959930662
# Total loss: 5.03249. L2-loss: 0.343077
# Smile loss: 0.277282
# Gender loss: 0.455586
# Age loss: 3.95654
# Epoch: 7
# Learning rate: 0.004633
#
#
# Smile task train accuracy: 94.6266666667
# Gender task train accuracy: 80.59442774
# Age task train accuracy: 3.98223893434
# Total loss: 4.95901. L2-loss: 0.319975
# Smile loss: 0.249025
# Gender loss: 0.441937
# Age loss: 3.94807
# Epoch: 8
# Learning rate: 0.003972
#
#
# Smile task train accuracy: 95.2596839789
# Gender task train accuracy: 80.9588255687
# Age task train accuracy: 4.05760384026
# Total loss: 4.91634. L2-loss: 0.304285
# Smile loss: 0.23402
# Gender loss: 0.435272
# Age loss: 3.94276
# Epoch: 9
# Learning rate: 0.003585
#
#
# Smile task train accuracy: 95.9997333156
# Gender task train accuracy: 81.2168730124
# Age task train accuracy: 3.99279975999
# Total loss: 4.87623. L2-loss: 0.294643
# Smile loss: 0.215114
# Gender loss: 0.428705
# Age loss: 3.93777
# Epoch: 10
# Learning rate: 0.003074
#
#
# Smile task train accuracy: 96.3165438848
# Gender task train accuracy: 81.4119702111
# Age task train accuracy: 4.01877383397
# Total loss: 4.84542. L2-loss: 0.287653
# Smile loss: 0.200865
# Gender loss: 0.425901
# Age loss: 3.931
# Epoch: 11
# Learning rate: 0.002774
#
#
# Smile task train accuracy: 96.5829916325
# Gender task train accuracy: 81.6036855299
# Age task train accuracy: 4.12613753792
# Total loss: 4.82087. L2-loss: 0.28409
# Smile loss: 0.191719
# Gender loss: 0.422944
# Age loss: 3.92211
# Epoch: 12
# Learning rate: 0.002378
#
#
# Smile task train accuracy: 96.8197879859
# Gender task train accuracy: 81.9222486683
# Age task train accuracy: 4.17480582686
# Total loss: 4.78638. L2-loss: 0.282539
# Smile loss: 0.179253
# Gender loss: 0.417143
# Age loss: 3.90745
# Epoch: 13
# Learning rate: 0.002146
#
#
# Smile task train accuracy: 97.3696492866
# Gender task train accuracy: 82.038427179
# Age task train accuracy: 4.26961797453
# Total loss: 4.73745. L2-loss: 0.278692
# Smile loss: 0.164063
# Gender loss: 0.41056
# Age loss: 3.88414
# Epoch: 14
# Learning rate: 0.001840
#
#
# Smile task train accuracy: 97.96
# Gender task train accuracy: 82.3719615451
# Age task train accuracy: 4.39762650843
# Total loss: 4.69346. L2-loss: 0.276801
# Smile loss: 0.147235
# Gender loss: 0.404144
# Age loss: 3.86528
# Epoch: 15
# Learning rate: 0.001578
#
#
# Smile task train accuracy: 98.4199473316
# Gender task train accuracy: 82.4557309723
# Age task train accuracy: 4.42420646297
# Total loss: 4.65651. L2-loss: 0.27557
# Smile loss: 0.132028
# Gender loss: 0.400013
# Age loss: 3.8489
# Epoch: 16
# Learning rate: 0.001424
#
#
# Smile task train accuracy: 97.5298353224
# Gender task train accuracy: 82.2342673894
# Age task train accuracy: 4.49948331611
# Total loss: 4.70166. L2-loss: 0.293461
# Smile loss: 0.158981
# Gender loss: 0.402912
# Age loss: 3.84631
# Epoch: 17
# Learning rate: 0.001221
#
#
# Smile task train accuracy: 98.743291443
# Gender task train accuracy: 82.6790762174
# Age task train accuracy: 4.47620888975
# Total loss: 4.61608. L2-loss: 0.284481
# Smile loss: 0.111077
# Gender loss: 0.393207
# Age loss: 3.82732
# Epoch: 18
# Learning rate: 0.001102
#
#
# Smile task train accuracy: 99.0766358879
# Gender task train accuracy: 82.8134063165
# Age task train accuracy: 4.46611909651
# Total loss: 4.58185. L2-loss: 0.273335
# Smile loss: 0.0985479
# Gender loss: 0.390555
# Age loss: 3.81941
# Epoch: 19
# Learning rate: 0.000945
#
#
# Smile task train accuracy: 99.2099473298
# Gender task train accuracy: 82.905982906
# Age task train accuracy: 4.61757960425
# Total loss: 4.55389. L2-loss: 0.265773
# Smile loss: 0.0895315
# Gender loss: 0.388764
# Age loss: 3.80982
# Epoch: 20
# Learning rate: 0.000853
#
#
# Smile task train accuracy: 99.5032836617
# Gender task train accuracy: 83.0035467612
# Age task train accuracy: 4.56894080311
# Total loss: 4.51904. L2-loss: 0.258117
# Smile loss: 0.0730288
# Gender loss: 0.385705
# Age loss: 3.80219
# Epoch: 21
# Learning rate: 0.000731
#
#
# Smile task train accuracy: 99.5066502217
# Gender task train accuracy: 83.0146539195
# Age task train accuracy: 4.62227733664
# Total loss: 4.50277. L2-loss: 0.255249
# Smile loss: 0.0698295
# Gender loss: 0.383741
# Age loss: 3.79395
# Epoch: 22
# Learning rate: 0.000627
#
#
# Smile task train accuracy: 99.709990333
# Gender task train accuracy: 83.2024374633
# Age task train accuracy: 4.70488622802
# Total loss: 4.4697. L2-loss: 0.249334
# Smile loss: 0.054584
# Gender loss: 0.380247
# Age loss: 3.78554
# Epoch: 23
# Learning rate: 0.000566
#
#
# Smile task train accuracy: 99.7266302174
# Gender task train accuracy: 83.3433337333
# Age task train accuracy: 4.75485686094
# Total loss: 4.44718. L2-loss: 0.243625
# Smile loss: 0.0474594
# Gender loss: 0.378683
# Age loss: 3.77741
# Epoch: 24
# Learning rate: 0.000485
#
#
# Smile task train accuracy: 99.8499899993
# Gender task train accuracy: 83.3848902637
# Age task train accuracy: 4.80965397693
# Total loss: 4.41828. L2-loss: 0.233048
# Smile loss: 0.0412491
# Gender loss: 0.375148
# Age loss: 3.76884
# Epoch: 25
# Learning rate: 0.000438
#
#
# Smile task train accuracy: 99.88
# Gender task train accuracy: 83.5210037534
# Age task train accuracy: 4.88842366338
# Total loss: 4.3952. L2-loss: 0.225336
# Smile loss: 0.0368035
# Gender loss: 0.372752
# Age loss: 3.76031
# Epoch: 26
# Learning rate: 0.000375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3092e8de3f07> in <module>()
#     113                                                   feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
#     114                                                              phase_train: True,
# --> 115                                                              keep_prob: 0.5})
#     116
#     117             smile_nb_true_pred += sess.run(smile_true_pred, feed_dict={x: batch_img, y_: batch_label, mask: batch_mask,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
